# %% [markdown]
# ### 作業
# 目前已經學過許多的模型，相信大家對整體流程應該比較掌握了，這次作業請改用**手寫辨識資料集**，步驟流程都是一樣的，請試著自己撰寫程式碼來完成所有步驟

# %%
from sklearn import datasets, metrics
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import train_test_split
digits = datasets.load_digits()

# %%
x_train, x_test, y_train, y_test= train_test_split(digits.data, digits.target, test_size=0.25, random_state=0)

model = GradientBoostingClassifier()
model.fit(x_train, y_train)
pred= model.predict(x_test)

# %%
acc = metrics.accuracy_score(y_test, pred)
print("Acuuracy: ", acc)
# Out:
# Acuuracy:  0.96

# %%
help(GradientBoostingClassifier)
# Out:
# Help on class GradientBoostingClassifier in module sklearn.ensemble.gradient_boosting:
#
# class GradientBoostingClassifier(BaseGradientBoosting, sklearn.base.ClassifierMixin)
#  |  Gradient Boosting for classification.
#  |
#  |  GB builds an additive model in a
#  |  forward stage-wise fashion; it allows for the optimization of
#  |  arbitrary differentiable loss functions. In each stage ``n_classes_``
#  |  regression trees are fit on the negative gradient of the
#  |  binomial or multinomial deviance loss function. Binary classification
#  |  is a special case where only a single regression tree is induced.
#  |
#  |  Read more in the :ref:`User Guide <gradient_boosting>`.
#  |
#  |  Parameters
#  |  ----------
#  |  loss : {'deviance', 'exponential'}, optional (default='deviance')
#  |      loss function to be optimized. 'deviance' refers to
#  |      deviance (= logistic regression) for classification
#  |      with probabilistic outputs. For loss 'exponential' gradient
# ...

# %% [markdown]
# # Further experiments

# %%
x_train, x_test, y_train, y_test= train_test_split(digits.data, digits.target, test_size=0.25, random_state=0)

model = GradientBoostingClassifier(loss='deviance', learning_rate=0.1, n_estimators=250)
# failed at loss ='exponetial', it said, exponential only for 2 classes... 

model.fit(x_train, y_train)
pred= model.predict(x_test)
acc = metrics.accuracy_score(y_test, pred)
print("Acuuracy: ", acc)

# n_estimator = 150 ==> 0.9644444444444444
# n_estimator = 200 ==> 0.9644444444444444 (same as n_est = 150)
# n_estimator = 250 ==> 0.9622222222222222 (same as n_est = 100)
# Out:
# Acuuracy:  0.9644444444444444

# %%
x_train, x_test, y_train, y_test= train_test_split(digits.data, digits.target, test_size=0.25, random_state=0)

model = GradientBoostingClassifier(max_depth=2)
# failed at loss ='exponetial', it said, exponential only for 2 classes... 

model.fit(x_train, y_train)
pred= model.predict(x_test)
acc = metrics.accuracy_score(y_test, pred)
print("Acuuracy: ", acc)
# Out:
# Acuuracy:  0.9511111111111111
